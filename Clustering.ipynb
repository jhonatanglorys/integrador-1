# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import csv

from sklearn.cluster import MiniBatchKMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
data = pd.read_csv('resultados.csv')  
data.head()
# Out:
#                                               titulo  \
# 0             b'[LIBRO][B] Mental health atlas 2005'
# 1  b'[LIBRO][B] The National Institute of Mental ...
# 2                 b'No health without mental health'
# 3  b'Racism, mental health, and mental health pra...
# 4                       b'Adolescent mental health.'
#
#                                              vinculo  \
# 0  b'https://books.google.com/books?hl=es&lr=&id=...
# 1  b'https://books.google.com/books?hl=es&lr=&id=...
# 2  b'https://www.academia.edu/download/46182950/G...
# 3  b'https://www.researchgate.net/profile/Helen_N...
# 4   b'https://psycnet.apa.org/record/1989-25629-001'
#
#                                              resumen
# 0  b'The 2005 edition is an update of the first M...
# 1  b"The National Institute of Mental Health admi...
# 2  b'About 14% of the global burden of disease ha...
# 3  b'In this article, the authors present an inte...
# 4  b"Definitions and descriptions of adolescent m...

# %%
data.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-3d8483998d6f> in <module>
# ----> 1 data.shape()
#
# TypeError: 'tuple' object is not callable

# %%
tfidf = TfidfVectorizer(
    min_df = 5,
    max_df = 0.95,
    max_features = 8000,
    stop_words = 'english'
)
tfidf.fit(data.resumen)
text = tfidf.transform(data.resumen)

# %%
def find_optimal_clusters(data, max_k):
    iters = range(2, max_k+1, 2)
    
    sse = []
    for k in iters:
        sse.append(MiniBatchKMeans(n_clusters=k, init_size=1024, batch_size=2048, random_state=20).fit(data).inertia_)
        print('Fit {} clusters'.format(k))
        
    f, ax = plt.subplots(1, 1)
    ax.plot(iters, sse, marker='o')
    ax.set_xlabel('Cluster Centers')
    ax.set_xticks(iters)
    ax.set_xticklabels(iters)
    ax.set_ylabel('SSE')
    ax.set_title('SSE by Cluster Center Plot')
    
find_optimal_clusters(text, 20)
# Out:
# Fit 2 clusters
# Fit 4 clusters
# Fit 6 clusters
# Fit 8 clusters
# Fit 10 clusters
# Fit 12 clusters
# Fit 14 clusters
# Fit 16 clusters
# Fit 18 clusters
# Fit 20 clusters

# %%
clusters = MiniBatchKMeans(n_clusters=10, init_size=1024, batch_size=2048, random_state=20).fit_predict(text)

# %%
def plot_tsne_pca(data, labels):
    max_label = max(labels)
    max_items = np.random.choice(range(data.shape[0]), size=400, replace=False)
    
    pca = PCA(n_components=2).fit_transform(data[max_items,:].todense())
    tsne = TSNE().fit_transform(PCA(n_components=50).fit_transform(data[max_items,:].todense()))
    
    
    idx = np.random.choice(range(pca.shape[0]), size=400, replace=False)
    label_subset = labels[max_items]
    label_subset = [cm.hsv(i/max_label) for i in label_subset[idx]]
    
    f, ax = plt.subplots(1, 2, figsize=(14, 6))
    
    ax[0].scatter(pca[idx, 0], pca[idx, 1], c=label_subset)
    ax[0].set_title('PCA Cluster Plot')
    
    ax[1].scatter(tsne[idx, 0], tsne[idx, 1], c=label_subset)
    ax[1].set_title('TSNE Cluster Plot')
    
plot_tsne_pca(text, clusters)

# %%
def get_top_keywords(data, clusters, labels, n_terms):
    df = pd.DataFrame(data.todense()).groupby(clusters).mean()
    
    for i,r in df.iterrows():
        print('\nCluster {}'.format(i))
        print(','.join([labels[t] for t in np.argsort(r)[-n_terms:]]))
            
get_top_keywords(text, clusters, tfidf.get_feature_names(), 10)
# Out:
# Cluster 0
# 10,research,chapter,mental,theoretical,health,highly,psychiatric,edition,20
#
# Cluster 1
# service,based,paper,research,problems,data,study,services,mental,health
#
# Cluster 2
# review,examines,public,psychological,support,stress,work,mental,health,social
#
# Cluster 3
# background,life,common,social,treatment,people,health,years,mental,disorders
#
# Cluster 4
# paper,health,mental,symptoms,positive,exercise,activity,anxiety,physical,depression
#
# Cluster 5
# distress,practice,measure,children,assessment,health,mental,psychological,united,states
#
# Cluster 6
# community,issues,professionals,research,illness,psychiatry,field,health,book,mental
#
# Cluster 7
# medical,family,providers,services,children,primary,mental,behavioral,health,care
#
# Cluster 8
# mental,organization,country,england,health,new,covid,world,19,disease
#
# Cluster 9
# american,states,abstract,united,culture,general,mental,health,americans,report
